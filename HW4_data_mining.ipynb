# %% [markdown]
# <a href="https://colab.research.google.com/github/bbombver/BSC_DPDM2025/blob/main/HW4_data_mining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/BSC_DPDM'

# %% [markdown]
# ## การเตรียมข้อมูลสำหรับ Apriori Algorithm

# %% [markdown]
# ข้อมูลที่ใช้มักจะอยู่ในรูปแบบของธุรกรรม (Transactions) โดยแต่ละธุรกรรมจะประกอบไปด้วยชุดของรายการ (Items)

# %% [markdown]
# InvoiceNo = รหัสใบเสร็จ, StockCode = รหัสสินค้า, Description = คำอธิบายรายการสินค้า, Quantity = จำนวนชิ้น, InvoiceDate = วันที่ซื้อ, UnitPrice = ราคาต่อหน่วย, CustomerID = รหัสสมาชิกลูกค้า, Country = ประเทศที่ตั้ง กรณีมีหลายสาขา

# %%
transactions = data.groupby('InvoiceNo')['StockCode'].apply(list) #รวม ให้สินค้ารหัสใบเสร็จเดียวกันมาอยู่ด้วยกัน # จัดกลุ่มข้อมูล .apply(func  ที่จะทำ)
transactions
# Out:
# InvoiceNo
# 536365     [85123A, 71053, 84406B, 84029G, 84029E, 22752,...
# 536366                                        [22633, 22632]
# 536367     [84879, 22745, 22748, 22749, 22310, 84969, 226...
# 536368                          [22960, 22913, 22912, 22914]
# 536369                                               [21756]
#                                  ...
# C581484                                              [23843]
# C581490                                       [22178, 23144]
# C581499                                                  [M]
# C581568                                              [21258]
# C581569                                       [84978, 20979]
# Name: StockCode, Length: 25900, dtype: object

# %% [markdown]
# ## Association Rules

# %%
# !pip install apyori
# Out:
# Collecting apyori
#   Downloading apyori-1.1.2.tar.gz (8.6 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: apyori
#   Building wheel for apyori (setup.py) ... done
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5954 sha256=41bec7eabdd212d2227038c1d023ef0d749a5e5efe7683833007a0be572a4794
#   Stored in directory: /root/.cache/pip/wheels/7f/49/e3/42c73b19a264de37129fadaa0c52f26cf50e87de08fb9804af
# Successfully built apyori
# Installing collected packages: apyori
# Successfully installed apyori-1.1.2

# %%
from apyori import apriori

# %%
frequentItemsets = list(apriori(transactions,min_support = 0.065))
frequentItemsets
# Out:
# [RelationRecord(items=frozenset({'22423'}), support=0.08386100386100385, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'22423'}), confidence=0.08386100386100385, lift=1.0)]),
#  RelationRecord(items=frozenset({'47566'}), support=0.06586872586872587, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'47566'}), confidence=0.06586872586872587, lift=1.0)]),
#  RelationRecord(items=frozenset({'85099B'}), support=0.08243243243243244, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'85099B'}), confidence=0.08243243243243244, lift=1.0)]),
#  RelationRecord(items=frozenset({'85123A'}), support=0.08671814671814672, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'85123A'}), confidence=0.08671814671814672, lift=1.0)])]

# %% [markdown]
# # HW 2 หา pattern ที่น่าสนใจใน Dataset หนังอินเดีย (india imdb)

# %%
India_data = pd.read_csv(os.path.join(path,'IMDb Movies India.csv'),encoding='latin-1')
India_data
# Out:
#                                      Name    Year Duration            Genre  \
# 0                                             NaN      NaN            Drama
# 1      #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                             #Homecoming  (2021)   90 min   Drama, Musical
# 3                                 #Yaaram  (2019)  110 min  Comedy, Romance
# 4                       ...And Once Again  (2010)  105 min            Drama
# ...                                   ...     ...      ...              ...
# 15504                 Zulm Ko Jala Doonga  (1988)      NaN           Action
# 15505                               Zulmi  (1999)  129 min    Action, Drama
# 15506                           Zulmi Raj  (2005)      NaN           Action
# 15507                       Zulmi Shikari  (1988)      NaN           Action
# 15508                        Zulm-O-Sitam  (1998)  130 min    Action, Drama
#
#        Rating Votes            Director           Actor 1             Actor 2  \
# 0         NaN   NaN       J.S. Randhawa          Manmauji              Birbal
# 1         7.0     8       Gaurav Bakshi      Rasika Dugal      Vivek Ghamande
# 2         NaN   NaN  Soumyajit Majumdar      Sayani Gupta   Plabita Borthakur
# 3         4.4    35          Ovais Khan           Prateik          Ishita Raj
# 4         NaN   NaN        Amol Palekar      Rajat Kapoor  Rituparna Sengupta
# ...       ...   ...                 ...               ...                 ...
# 15504     4.6    11       Mahendra Shah  Naseeruddin Shah       Sumeet Saigal
# 15505     4.5   655          Kuku Kohli      Akshay Kumar      Twinkle Khanna
# 15506     NaN   NaN          Kiran Thej   Sangeeta Tiwari                 NaN
# 15507     NaN   NaN                 NaN               NaN                 NaN
# 15508     6.2    20        K.C. Bokadia        Dharmendra          Jaya Prada
#
#                Actor 3
# 0      Rajendra Bhatia
# 1        Arvind Jangid
# 2           Roy Angana
# 3      Siddhant Kapoor
# 4          Antara Mali
# ...                ...
# 15504    Suparna Anand
# 15505      Aruna Irani
# 15506              NaN
# 15507              NaN
# 15508      Arjun Sarja
#
# [15509 rows x 10 columns]

# %% [markdown]
# ## ตรวจสอบ + จัดการค่าว่าง

# %%
India_data.isnull().any()
# Out:
# Name        False
# Year         True
# Duration     True
# Genre        True
# Rating       True
# Votes        True
# Director     True
# Actor 1      True
# Actor 2      True
# Actor 3      True
# dtype: bool

# %%
India_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15509 entries, 0 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      15509 non-null  object
#  1   Year      14981 non-null  object
#  2   Duration  7240 non-null   object
#  3   Genre     13632 non-null  object
#  4   Rating    7919 non-null   float64
#  5   Votes     7920 non-null   object
#  6   Director  14984 non-null  object
#  7   Actor 1   13892 non-null  object
#  8   Actor 2   13125 non-null  object
#  9   Actor 3   12365 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 1.2+ MB

# %%
# คำนวณสัดส่วนของค่าว่างในแต่ละคอลัมน์
missing_data = India_data.isnull().sum() / len(India_data) * 100
missing_data
# Out:
# Name         0.000000
# Year         3.404475
# Duration    53.317429
# Genre       12.102650
# Rating      48.939326
# Votes       48.932878
# Director     3.385131
# Actor 1     10.426204
# Actor 2     15.371720
# Actor 3     20.272100
# dtype: float64

# %% [markdown]
# ### ชื่อ

# %%
print(len(India_data[India_data['Name'].isnull()]))
India_data[India_data['Name'].isnull()]
# Out:
# 0
# Empty DataFrame
# Columns: [Name, Year, Duration, Genre, Rating, Votes, Director, Actor 1, Actor 2, Actor 3]
# Index: []

# %%
India_data.loc[0,'Name']= '"space"'  #loc ชี้ไปที่ตารางด้วยแถวและคอลัมน์ทีาเราสนใจ จะเปลี่ยนชื่อ

# %%
India_data['Name'].unique()
# Out:
# array(['"space"', '#Gadhvi (He thought he was Gandhi)', '#Homecoming',
#        ..., 'Zulmi Raj', 'Zulmi Shikari', 'Zulm-O-Sitam'], dtype=object)

# %% [markdown]
# ### ปี (missing 3.40%)

# %%
print(len(India_data[India_data['Year'].isnull()]))
India_data[India_data['Year'].isnull()]
# Out:
# 528
#                        Name Year Duration                  Genre  Rating  \
# 0                   "space"  NaN      NaN                  Drama     NaN
# 16              108 Limited  NaN      NaN                    NaN     NaN
# 23                 12 Years  NaN      NaN              Biography     NaN
# 37                     1911  NaN      NaN  Drama, History, Sport     NaN
# 48             2 GB Ki Life  NaN      NaN                  Drama     NaN
# ...                     ...  ...      ...                    ...     ...
# 15177               Yakshya  NaN      NaN                 Horror     NaN
# 15315            Yubi Lakpi  NaN      NaN              Biography     NaN
# 15316            Yubi Lukpi  NaN      NaN                  Drama     NaN
# 15337                Zahoor  NaN      NaN                 Action     NaN
# 15477  Zindagi on the Rocks  NaN      NaN                  Drama     NaN
#
#       Votes              Director           Actor 1         Actor 2  \
# 0       NaN         J.S. Randhawa          Manmauji          Birbal
# 16      NaN           Anand Anddy        Vijay Raaz   Sanjay Mishra
# 23      NaN         Sohail Tatari               NaN             NaN
# 37      NaN        Nikkhil Advani      John Abraham             NaN
# 48      NaN                   NaN               NaN             NaN
# ...     ...                   ...               ...             ...
# 15177   NaN      Linkan Mahapatra               NaN             NaN
# 15315   NaN                   NaN               NaN             NaN
# 15316   NaN           Omung Kumar               NaN             NaN
# 15337   NaN          Pankaj Batra  Parineeti Chopra   Parmish Verma
# 15477   NaN  Ravindra Suryavanshi        Bala Hijam  Pushtii Shakti
#
#                  Actor 3
# 0        Rajendra Bhatia
# 16          Brahmanandam
# 23                   NaN
# 37                   NaN
# 48                   NaN
# ...                  ...
# 15177                NaN
# 15315                NaN
# 15316                NaN
# 15337       Rahul Sharma
# 15477  Bajrangbali Singh
#
# [528 rows x 10 columns]

# %%
India_data['Year'] = India_data['Year'] = India_data['Year'].str.replace('(', '').str.replace(')', '').astype(float)

# %% [markdown]
# ผู้กำกับคนเดียวกันน่าจะผลิตหนังในปีใกล้ๆ เคียงกัน

# %%
India_data['Year'].fillna(India_data.groupby('Director')['Year'].transform('mean'))
# Out:
# 0        2017.0
# 1        2019.0
# 2        2021.0
# 3        2019.0
# 4        2010.0
#           ...
# 15504    1988.0
# 15505    1999.0
# 15506    2005.0
# 15507    1988.0
# 15508    1998.0
# Name: Year, Length: 15509, dtype: float64

# %% [markdown]
# Director เพราะน่าจะผลิตหนังในช่วงเดียวๆ กัน

# %%
India_data['Year'] = India_data['Year'].fillna(India_data.groupby('Director')['Year'].transform('mean'))

# %%
print(len(India_data[India_data['Year'].isnull()]))
India_data[India_data['Year'].isnull()].head(5)
# Out:
# 324
#                  Name  Year Duration                     Genre  Rating Votes  \
# 16        108 Limited   NaN      NaN                       NaN     NaN   NaN
# 48       2 GB Ki Life   NaN      NaN                     Drama     NaN   NaN
# 93              4 Sum   NaN   96 min    Crime, Drama, Thriller     NaN   NaN
# 112  69 Reality in Us   NaN      NaN  Drama, Romance, Thriller     NaN   NaN
# 122       777 Charlie   NaN  136 min  Adventure, Comedy, Drama     NaN   NaN
#
#         Director            Actor 1               Actor 2             Actor 3
# 16   Anand Anddy         Vijay Raaz         Sanjay Mishra        Brahmanandam
# 48           NaN                NaN                   NaN                 NaN
# 93   Neeraj Gwal  Pranav Chandrakar  Yashwant Anand Gupta          Neeraj Uke
# 112   Samir Khan                NaN                   NaN                 NaN
# 122   Kiranraj K     Rakshit Shetty               Charlie  Sangeetha Sringeri

# %% [markdown]
# ### ประเภทหนัง (missing 12.10%)

# %%
print(len(India_data[India_data['Genre'].isnull()]))
India_data[India_data['Genre'].isnull()]
# Out:
# 1877
#                     Name    Year Duration Genre  Rating Votes  \
# 16           108 Limited     NaN      NaN   NaN     NaN   NaN
# 19            11 O'Clock  1948.0      NaN   NaN     NaN   NaN
# 31       150 Seconds Ago  2002.0  112 min   NaN     NaN   NaN
# 65             25th July  1951.0      NaN   NaN     7.6     5
# 66            26 January  1956.0      NaN   NaN     6.6     7
# ...                  ...     ...      ...   ...     ...   ...
# 15473    Zindagi Ke Mele  1956.0      NaN   NaN     NaN   NaN
# 15480  Zindagi Unlimited  2021.0  105 min   NaN     NaN   NaN
# 15485            Zingaro  1963.0      NaN   NaN     NaN   NaN
# 15486            Zingaro  1935.0      NaN   NaN     NaN   NaN
# 15495  Zulf Ke Saye Saye  1983.0      NaN   NaN     NaN   NaN
#
#               Director         Actor 1        Actor 2            Actor 3
# 16         Anand Anddy      Vijay Raaz  Sanjay Mishra       Brahmanandam
# 19          Homi Wadia           Aftab   Sayani Atish  Austin Ki Bachchi
# 31      Batul Mukhtiar             NaN            NaN                NaN
# 65        Chitra Mitra             NaN            NaN                NaN
# 66       Ramesh Saigal            Ajit            NaN                NaN
# ...                ...             ...            ...                ...
# 15473        K.B. Lall  Chandrashekhar         Chitra             Dulari
# 15480  Vipin Agnihotri     Amit Pandey  Kanchi Rohela   Kritika Sanghavi
# 15485      Chandrakant       Bela Bose   Laxmi Chhaya        Aruna Irani
# 15486      S.N. Bhende          Pushpa            NaN                NaN
# 15495      Anand Sagar     Roohi Berde  Rakesh Pandey                NaN
#
# [1877 rows x 10 columns]

# %%
India_data_Genre_Na =  India_data[India_data['Genre'].isnull()]
India_data_Genre_Na
# Out:
#                     Name    Year Duration Genre  Rating Votes  \
# 16           108 Limited     NaN      NaN   NaN     NaN   NaN
# 19            11 O'Clock  1948.0      NaN   NaN     NaN   NaN
# 31       150 Seconds Ago  2002.0  112 min   NaN     NaN   NaN
# 65             25th July  1951.0      NaN   NaN     7.6     5
# 66            26 January  1956.0      NaN   NaN     6.6     7
# ...                  ...     ...      ...   ...     ...   ...
# 15473    Zindagi Ke Mele  1956.0      NaN   NaN     NaN   NaN
# 15480  Zindagi Unlimited  2021.0  105 min   NaN     NaN   NaN
# 15485            Zingaro  1963.0      NaN   NaN     NaN   NaN
# 15486            Zingaro  1935.0      NaN   NaN     NaN   NaN
# 15495  Zulf Ke Saye Saye  1983.0      NaN   NaN     NaN   NaN
#
#               Director         Actor 1        Actor 2            Actor 3
# 16         Anand Anddy      Vijay Raaz  Sanjay Mishra       Brahmanandam
# 19          Homi Wadia           Aftab   Sayani Atish  Austin Ki Bachchi
# 31      Batul Mukhtiar             NaN            NaN                NaN
# 65        Chitra Mitra             NaN            NaN                NaN
# 66       Ramesh Saigal            Ajit            NaN                NaN
# ...                ...             ...            ...                ...
# 15473        K.B. Lall  Chandrashekhar         Chitra             Dulari
# 15480  Vipin Agnihotri     Amit Pandey  Kanchi Rohela   Kritika Sanghavi
# 15485      Chandrakant       Bela Bose   Laxmi Chhaya        Aruna Irani
# 15486      S.N. Bhende          Pushpa            NaN                NaN
# 15495      Anand Sagar     Roohi Berde  Rakesh Pandey                NaN
#
# [1877 rows x 10 columns]

# %%
India_data_Name_dup = India_data[India_data['Name'].duplicated()] #ดูชื่อหนังที่ซ้ำกัน
India_data_Name_dup
# Out:
#                        Name    Year Duration                        Genre  \
# 22               12 O'Clock  2021.0  105 min             Horror, Thriller
# 101                5 Rifles  2001.0      NaN                       Action
# 136    A Ballad of Maladies  2016.0   86 min  Documentary, History, Music
# 180         Aa Gale Lag Jaa  1994.0  158 min             Mystery, Romance
# 186                  Aabroo  1968.0  170 min         Comedy, Crime, Drama
# ...                     ...     ...      ...                          ...
# 15459               Zindagi  1956.0      NaN                          NaN
# 15460               Zindagi  2000.0  118 min                      Romance
# 15461               Zindagi  1942.0      NaN                        Drama
# 15467      Zindagi Aur Maut  2002.0  119 min                       Action
# 15486               Zingaro  1935.0      NaN                          NaN
#
#        Rating Votes            Director             Actor 1  \
# 22        4.4    63     Ram Gopal Varma  Mithun Chakraborty
# 101       NaN   NaN        Hemant Birje         Anu Kashyap
# 136       NaN   NaN        Sarvnik Kaur       Tushar Madhav
# 180       4.4   115      Hamid Ali Khan       Jugal Hansraj
# 186       5.5    21          C.L. Rawal         Ashok Kumar
# ...       ...   ...                 ...                 ...
# 15459     NaN   NaN          C.L. Dheer          Geeta Bali
# 15460     2.8     8       Suraj Prakash        Vicky Bhalla
# 15461     NaN   NaN   Amiya Chakrabarty      Master Bhagwan
# 15467     NaN   NaN  Ramesh U. Lakhiani         Arun Mathur
# 15486     NaN   NaN         S.N. Bhende              Pushpa
#
#                  Actor 2       Actor 3
# 22     Makrand Deshpande   Dalip Tahil
# 101           Raza Murad       Paintal
# 136                  NaN           NaN
# 180     Urmila Matondkar  Paresh Rawal
# 186                 Vimi        Rehman
# ...                  ...           ...
# 15459                NaN           NaN
# 15460            Gayatri  Deepak Jethi
# 15461     Nalini Jaywant   Ashok Kumar
# 15467       Anil Nagrath  Amit Pachori
# 15486                NaN           NaN
#
# [1671 rows x 10 columns]

# %%
name_genre = {} # สร้าง dict เก็บชื่อหนัง+ประเภท
for i in range(len(India_data)):
    if pd.notna(India_data.loc[i, 'Genre']):  # ใช้ pd.notna เพื่อตรวจสอบว่าไม่เป็นค่าว่าง
        name_genre[India_data.loc[i, 'Name']] = India_data.loc[i, 'Genre']

for i in range(len(India_data)): # เติมประเภทหนัง จากชื่อที่เหมือนกัน ด้วยประเภทที่เจอล่าสุด กรณีซ้ำ
    if pd.isnull(India_data.loc[i, 'Genre']):  # ใช้ pd.isnull เพื่อตรวจสอบค่าว่าง
        if India_data.loc[i, 'Name'] in name_genre:
            India_data.loc[i, 'Genre'] = name_genre[India_data.loc[i, 'Name']]

# %%
print(len(India_data[India_data['Genre'].isnull()]))
India_data[India_data['Genre'].isnull()].head(5)
# Out:
# 1393
#                Name    Year Duration Genre  Rating Votes        Director  \
# 16      108 Limited     NaN      NaN   NaN     NaN   NaN     Anand Anddy
# 19       11 O'Clock  1948.0      NaN   NaN     NaN   NaN      Homi Wadia
# 31  150 Seconds Ago  2002.0  112 min   NaN     NaN   NaN  Batul Mukhtiar
# 65        25th July  1951.0      NaN   NaN     7.6     5    Chitra Mitra
# 66       26 January  1956.0      NaN   NaN     6.6     7   Ramesh Saigal
#
#        Actor 1        Actor 2            Actor 3
# 16  Vijay Raaz  Sanjay Mishra       Brahmanandam
# 19       Aftab   Sayani Atish  Austin Ki Bachchi
# 31         NaN            NaN                NaN
# 65         NaN            NaN                NaN
# 66        Ajit            NaN                NaN

# %% [markdown]
# ### Rating (48.939326%)

# %%
print(len(India_data[India_data['Rating'].isnull()]))
India_data[India_data['Rating'].isnull()].head(5)
# Out:
# 7590
#                  Name    Year Duration           Genre  Rating Votes  \
# 0             "space"  2017.0      NaN           Drama     NaN   NaN
# 2         #Homecoming  2021.0   90 min  Drama, Musical     NaN   NaN
# 4   ...And Once Again  2010.0  105 min           Drama     NaN   NaN
# 7      .in for Motion  2008.0   59 min     Documentary     NaN   NaN
# 14         101 Ratein  1990.0      NaN        Thriller     NaN   NaN
#
#               Director       Actor 1             Actor 2          Actor 3
# 0        J.S. Randhawa      Manmauji              Birbal  Rajendra Bhatia
# 2   Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur       Roy Angana
# 4         Amol Palekar  Rajat Kapoor  Rituparna Sengupta      Antara Mali
# 7        Anirban Datta           NaN                 NaN              NaN
# 14              Harish     Saraswati        Disco Shanti              NaN

# %% [markdown]
# IMDb Rating: ใช้ระบบ 10 จุด โดยผู้ชมทั่วไปจะให้คะแนนภาพยนตร์หรือรายการโดยหลังจากได้ชม คะแนนเหล่านี้จะถูกรวมและคำนวณเป็นค่าเฉลี่ยเพื่อสะท้อนถึงคุณภาพหรือความนิยมโดยรวมของผลงานนั้นๆ

# %%
India_data['Rating'].max()
# Out:
# 10.0

# %%
India_data['Rating'].min()
# Out:
# 1.1

# %%
India_data.groupby('Genre')['Rating'].mean().round(1)
# Out:
# Genre
# Action                          5.1
# Action, Adventure               5.6
# Action, Adventure, Biography    7.8
# Action, Adventure, Comedy       5.6
# Action, Adventure, Crime        5.6
#                                ...
# Thriller, Action                4.3
# Thriller, Musical, Mystery      7.1
# Thriller, Mystery               6.5
# Thriller, Mystery, Family       6.1
# War                             4.3
# Name: Rating, Length: 485, dtype: float64

# %% [markdown]
# ใช้ .transform('mean') เพื่อสร้าง Series ที่มีขนาดเท่าเดิมกับข้อมูลต้นทาง เพื่อเติมค่าเฉลี่ยเข้าไปที่ตำแหน่งที่มีค่าว่างโดยตรง

# %%
India_data['Rating'] = India_data['Rating'].fillna(India_data.groupby('Genre')['Rating'].transform('mean')).round(1)

# %%
print(len(India_data[India_data['Rating'].isnull()]))
India_data[India_data['Rating'].isnull()].head(5)
# Out:
# 1386
#                      Name    Year Duration                        Genre  \
# 16            108 Limited     NaN      NaN                          NaN
# 19             11 O'Clock  1948.0      NaN                          NaN
# 31        150 Seconds Ago  2002.0  112 min                          NaN
# 102              5 Rupees  2018.0      NaN                          NaN
# 136  A Ballad of Maladies  2016.0   86 min  Documentary, History, Music
#
#      Rating Votes         Director        Actor 1          Actor 2  \
# 16      NaN   NaN      Anand Anddy     Vijay Raaz    Sanjay Mishra
# 19      NaN   NaN       Homi Wadia          Aftab     Sayani Atish
# 31      NaN   NaN   Batul Mukhtiar            NaN              NaN
# 102     NaN   NaN  Piyush Panjuani   Shabana Azmi  Yohaan Panjuani
# 136     NaN   NaN     Sarvnik Kaur  Tushar Madhav              NaN
#
#                Actor 3
# 16        Brahmanandam
# 19   Austin Ki Bachchi
# 31                 NaN
# 102                NaN
# 136                NaN

# %% [markdown]
# ### Duration

# %%
India_data['Duration'] = India_data['Duration'].str.replace(' min', '').astype(float)

# %%
India_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15509 entries, 0 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      15509 non-null  object
#  1   Year      15185 non-null  float64
#  2   Duration  7240 non-null   float64
#  3   Genre     14116 non-null  object
#  4   Rating    14123 non-null  float64
#  5   Votes     7920 non-null   object
#  6   Director  14984 non-null  object
#  7   Actor 1   13892 non-null  object
#  8   Actor 2   13125 non-null  object
#  9   Actor 3   12365 non-null  object
# dtypes: float64(3), object(7)
# memory usage: 1.2+ MB

# %%
India_data['Duration'].fillna(India_data.groupby('Genre')['Duration'].transform('mean')).round(1)
# Out:
# 0        120.5
# 1        109.0
# 2         90.0
# 3        110.0
# 4        105.0
#          ...
# 15504    131.0
# 15505    129.0
# 15506    131.0
# 15507    131.0
# 15508    130.0
# Name: Duration, Length: 15509, dtype: float64

# %%
India_data['Duration'] = India_data['Duration'].fillna(India_data.groupby('Genre')['Duration'].transform('mean')).round(1)

# %%
print(len(India_data[India_data['Duration'].isnull()]))
India_data[India_data['Duration'].isnull()].head(5)
# Out:
# 1323
#             Name    Year  Duration Genre  Rating Votes         Director  \
# 16   108 Limited     NaN       NaN   NaN     NaN   NaN      Anand Anddy
# 19    11 O'Clock  1948.0       NaN   NaN     NaN   NaN       Homi Wadia
# 65     25th July  1951.0       NaN   NaN     7.6     5     Chitra Mitra
# 66    26 January  1956.0       NaN   NaN     6.6     7    Ramesh Saigal
# 102     5 Rupees  2018.0       NaN   NaN     NaN   NaN  Piyush Panjuani
#
#           Actor 1          Actor 2            Actor 3
# 16     Vijay Raaz    Sanjay Mishra       Brahmanandam
# 19          Aftab     Sayani Atish  Austin Ki Bachchi
# 65            NaN              NaN                NaN
# 66           Ajit              NaN                NaN
# 102  Shabana Azmi  Yohaan Panjuani                NaN

# %% [markdown]
# ### คะแนน vote

# %%
print(len(India_data[India_data['Votes'].isnull()]))
India_data[India_data['Votes'].isnull()].head(5)
# Out:
# 7589
#                  Name    Year  Duration           Genre  Rating Votes  \
# 0             "space"  2017.0     120.5           Drama     6.4   NaN
# 2         #Homecoming  2021.0      90.0  Drama, Musical     6.5   NaN
# 4   ...And Once Again  2010.0     105.0           Drama     6.4   NaN
# 7      .in for Motion  2008.0      59.0     Documentary     7.7   NaN
# 14         101 Ratein  1990.0     108.6        Thriller     5.3   NaN
#
#               Director       Actor 1             Actor 2          Actor 3
# 0        J.S. Randhawa      Manmauji              Birbal  Rajendra Bhatia
# 2   Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur       Roy Angana
# 4         Amol Palekar  Rajat Kapoor  Rituparna Sengupta      Antara Mali
# 7        Anirban Datta           NaN                 NaN              NaN
# 14              Harish     Saraswati        Disco Shanti              NaN

# %%
India_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15509 entries, 0 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      15509 non-null  object
#  1   Year      15185 non-null  float64
#  2   Duration  14186 non-null  float64
#  3   Genre     14116 non-null  object
#  4   Rating    14123 non-null  float64
#  5   Votes     7920 non-null   object
#  6   Director  14984 non-null  object
#  7   Actor 1   13892 non-null  object
#  8   Actor 2   13125 non-null  object
#  9   Actor 3   12365 non-null  object
# dtypes: float64(3), object(7)
# memory usage: 1.2+ MB

# %%
India_data['Votes'].replace('$5.16M', 0, inplace=True)
# Out:
# /tmp/ipython-input-872705719.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   India_data['Votes'].replace('$5.16M', 0, inplace=True)

# %%
India_data['Votes'] = India_data['Votes'].str.replace(',','').astype('float64') # force change type

# %%
India_data.groupby('Genre')['Votes'].mean().round(1)
# Out:
# Genre
# Action                            44.4
# Action, Adventure                906.7
# Action, Adventure, Biography    1343.0
# Action, Adventure, Comedy       7203.0
# Action, Adventure, Crime         447.8
#                                  ...
# Thriller, Action                  34.0
# Thriller, Musical, Mystery       341.0
# Thriller, Mystery                 75.7
# Thriller, Mystery, Family         38.0
# War                               64.7
# Name: Votes, Length: 485, dtype: float64

# %%
India_data['Votes'] = India_data['Votes'].fillna(India_data.groupby('Genre')['Votes'].transform('mean')).round(1)

# %%
# India_data['Votes_2'] = India_data['Votes'].fillna(India_data.groupby(['Genre','Director'])['Votes'].transform('mean')).round(1)

# %%
India_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15509 entries, 0 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      15509 non-null  object
#  1   Year      15185 non-null  float64
#  2   Duration  14186 non-null  float64
#  3   Genre     14116 non-null  object
#  4   Rating    14123 non-null  float64
#  5   Votes     14123 non-null  float64
#  6   Director  14984 non-null  object
#  7   Actor 1   13892 non-null  object
#  8   Actor 2   13125 non-null  object
#  9   Actor 3   12365 non-null  object
# dtypes: float64(4), object(6)
# memory usage: 1.2+ MB

# %% [markdown]
# ### เติมค่าว่างที่เหลือ

# %%
missing_data = India_data.isnull().sum() / len(India_data) * 100
missing_data
# Out:
# Name         0.000000
# Year         2.089110
# Duration     8.530531
# Genre        8.981881
# Rating       8.936746
# Votes        8.936746
# Director     3.385131
# Actor 1     10.426204
# Actor 2     15.371720
# Actor 3     20.272100
# dtype: float64

# %%
India_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15509 entries, 0 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      15509 non-null  object
#  1   Year      15185 non-null  float64
#  2   Duration  14186 non-null  float64
#  3   Genre     14116 non-null  object
#  4   Rating    14123 non-null  float64
#  5   Votes     14123 non-null  float64
#  6   Director  14984 non-null  object
#  7   Actor 1   13892 non-null  object
#  8   Actor 2   13125 non-null  object
#  9   Actor 3   12365 non-null  object
# dtypes: float64(4), object(6)
# memory usage: 1.2+ MB

# %%
India_data.fillna({'Year':India_data['Year'].mean(), 'Duration':India_data['Duration'].mean(), 'Votes':0 ,'Rating':India_data['Rating'].mean()}, inplace=True)

# %%
India_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15509 entries, 0 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      15509 non-null  object
#  1   Year      15509 non-null  float64
#  2   Duration  15509 non-null  float64
#  3   Genre     14116 non-null  object
#  4   Rating    15509 non-null  float64
#  5   Votes     15509 non-null  float64
#  6   Director  14984 non-null  object
#  7   Actor 1   13892 non-null  object
#  8   Actor 2   13125 non-null  object
#  9   Actor 3   12365 non-null  object
# dtypes: float64(4), object(6)
# memory usage: 1.2+ MB

# %%
# ลบแถวที่มีค่าว่างในคอลัมน์ที่เลือก
India_data_cleaned = India_data.dropna(subset=['Genre', 'Director', 'Actor 1', 'Actor 2', 'Actor 3'])

# %%
India_data_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11646 entries, 0 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      11646 non-null  object
#  1   Year      11646 non-null  float64
#  2   Duration  11646 non-null  float64
#  3   Genre     11646 non-null  object
#  4   Rating    11646 non-null  float64
#  5   Votes     11646 non-null  float64
#  6   Director  11646 non-null  object
#  7   Actor 1   11646 non-null  object
#  8   Actor 2   11646 non-null  object
#  9   Actor 3   11646 non-null  object
# dtypes: float64(4), object(6)
# memory usage: 1000.8+ KB

# %%
# India_data.fillna({'Genre':'Unknown','Director':'Unknown', 'Actor 1':'Unknown', 'Actor 2':'Unknown', 'Actor 3':'Unknown'}, inplace=True)

# %%
India_data_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11646 entries, 0 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      11646 non-null  object
#  1   Year      11646 non-null  float64
#  2   Duration  11646 non-null  float64
#  3   Genre     11646 non-null  object
#  4   Rating    11646 non-null  float64
#  5   Votes     11646 non-null  float64
#  6   Director  11646 non-null  object
#  7   Actor 1   11646 non-null  object
#  8   Actor 2   11646 non-null  object
#  9   Actor 3   11646 non-null  object
# dtypes: float64(4), object(6)
# memory usage: 1000.8+ KB

# %%
missing_data = India_data_cleaned.isnull().sum() / len(India_data_cleaned) * 100
missing_data
# Out:
# Name        0.0
# Year        0.0
# Duration    0.0
# Genre       0.0
# Rating      0.0
# Votes       0.0
# Director    0.0
# Actor 1     0.0
# Actor 2     0.0
# Actor 3     0.0
# dtype: float64

# %% [markdown]
# ## แบ่งกลุ่มข้อมูล int float

# %% [markdown]
# ### Year

# %%
India_data_cleaned['Year'].max()
# Out:
# 2022.0

# %%
India_data_cleaned['Year'].min()
# Out:
# 1917.0

# %% [markdown]
# 1. ยุคเงียบ (Silent Era) และยุคเสียง (Sound Era)
# ยุคเงียบ (Pre-1927): ก่อนปี 1927 ซึ่งเป็นยุคของภาพยนตร์เงียบ
# ยุคเสียง (1927-1940): เริ่มต้นด้วย "The Jazz Singer" ในปี 1927   ซึ่งเป็นภาพยนตร์ที่มีเสียงพูดครั้งแรก
# 2. ยุคทองของฮอลลีวูด (Golden Age of Hollywood)
# ยุคทอง (1940-1960): ยุคนี้เป็นช่วงเวลาของการผลิตภาพยนตร์ที่มีคุณภาพสูง ด้วยเรื่องราวและดาราที่โดดเด่น
# 3. ยุคใหม่และการพัฒนาทางเทคโนโลยี
# ยุคใหม่ (1960-1980):   ช่วงนี้เห็นการเปลี่ยนแปลงทางวัฒนธรรมและเทคนิคในการผลิตภาพยนตร์ รวมถึงการเกิดขึ้นของ New Hollywood
# ยุคดิจิทัล (1980-2000):   การเริ่มต้นของการใช้เทคโนโลยีดิจิทัลในการผลิตภาพยนตร์
# 4. ยุคอินเทอร์เน็ตและการสตรีมมิ่ง
# ยุคอินเทอร์เน็ต (2000-2010):   เริ่มต้นของการใช้อินเทอร์เน็ตในการกระจายภาพยนตร์และการเข้าถึงแบบกว้างขวาง
# ยุคสตรีมมิ่ง (2010-2022): การเข้าถึงภาพยนตร์ผ่านบริการสตรีมมิ่งออนไลน์ที่เพิ่มมากขึ้น

# %%
years = pd.Series(range(1913, 2023))  # สร้าง Series สำหรับตัวอย่าง

# กำหนดช่วงปีและป้ายกำกับยุคตามประวัติศาสตร์ภาพยนตร์
bins = [1913, 1927, 1940, 1960, 1980, 2000, 2010, 2023]
labels = ['Silent Era', 'Early Sound Era', 'Golden Age of Hollywood', 'New Hollywood', 'Blockbuster Era', 'Internet Age', 'Streaming Era']

# ใช้ pd.cut() เพื่อแบ่ง 'Year' ตามช่วงที่กำหนด
India_data_cleaned['Era'] = pd.cut(India_data_cleaned['Year'], bins=bins, labels=labels, right=False)
# Out:
# /tmp/ipython-input-1994287505.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   India_data_cleaned['Era'] = pd.cut(India_data_cleaned['Year'], bins=bins, labels=labels, right=False)

# %%
India_data_cleaned.head(5)
# Out:
#                                  Name    Year  Duration            Genre  \
# 0                                      2017.0     120.5            Drama
# 1  #Gadhvi (He thought he was Gandhi)  2019.0     109.0            Drama
# 2                         #Homecoming  2021.0      90.0   Drama, Musical
# 3                             #Yaaram  2019.0     110.0  Comedy, Romance
# 4                   ...And Once Again  2010.0     105.0            Drama
#
#    Rating   Votes            Director       Actor 1             Actor 2  \
# 0     6.4   604.6       J.S. Randhawa      Manmauji              Birbal
# 1     7.0     8.0       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     6.5  1736.9  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4    35.0          Ovais Khan       Prateik          Ishita Raj
# 4     6.4   604.6        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3            Era
# 0  Rajendra Bhatia  Streaming Era
# 1    Arvind Jangid  Streaming Era
# 2       Roy Angana  Streaming Era
# 3  Siddhant Kapoor  Streaming Era
# 4      Antara Mali  Streaming Era

# %% [markdown]
# ### Duration

# %%
India_data_cleaned['Duration'].max()
# Out:
# 321.0

# %%
India_data_cleaned['Duration'].min()
# Out:
# 21.0

# %%
India_data_cleaned[India_data_cleaned['Duration']<=10]
# Out:
# Empty DataFrame
# Columns: [Name, Year, Duration, Genre, Rating, Votes, Director, Actor 1, Actor 2, Actor 3, Era]
# Index: []

# %%
# แบ่งตามช่วงเวลาในการฉาย
bins = [0, 90, 120, 180, 322]
labels = ['Short', 'Medium', 'Long', 'Epic']

India_data_cleaned['Duration_Category'] = pd.cut(India_data_cleaned['Duration'], bins=bins, labels=labels, right=False)
# Out:
# /tmp/ipython-input-4068146504.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   India_data_cleaned['Duration_Category'] = pd.cut(India_data_cleaned['Duration'], bins=bins, labels=labels, right=False)

# %%
India_data_cleaned.head(5)
# Out:
#                                  Name    Year  Duration            Genre  \
# 0                             "space"  2017.0     120.5            Drama
# 1  #Gadhvi (He thought he was Gandhi)  2019.0     109.0            Drama
# 2                         #Homecoming  2021.0      90.0   Drama, Musical
# 3                             #Yaaram  2019.0     110.0  Comedy, Romance
# 4                   ...And Once Again  2010.0     105.0            Drama
#
#    Rating   Votes            Director       Actor 1             Actor 2  \
# 0     6.4   604.6       J.S. Randhawa      Manmauji              Birbal
# 1     7.0     8.0       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     6.5  1736.9  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4    35.0          Ovais Khan       Prateik          Ishita Raj
# 4     6.4   604.6        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3            Era Duration_Category
# 0  Rajendra Bhatia  Streaming Era              Long
# 1    Arvind Jangid  Streaming Era            Medium
# 2       Roy Angana  Streaming Era            Medium
# 3  Siddhant Kapoor  Streaming Era            Medium
# 4      Antara Mali  Streaming Era            Medium

# %% [markdown]
# ### Rating

# %% [markdown]
# แบ่งตามค่าคะแนน

# %%
quantile_labels = ['Poor', 'Below Average', 'Average', 'Good', 'Excellent']
India_data_cleaned['Rating_Quantiles'] = pd.qcut(India_data_cleaned['Rating'], q=5, labels=quantile_labels)
# Out:
# /tmp/ipython-input-3962008940.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   India_data_cleaned['Rating_Quantiles'] = pd.qcut(India_data_cleaned['Rating'], q=5, labels=quantile_labels)

# %%
India_data_cleaned.head(5)
# Out:
#                                  Name    Year  Duration            Genre  \
# 0                             "space"  2017.0     120.5            Drama
# 1  #Gadhvi (He thought he was Gandhi)  2019.0     109.0            Drama
# 2                         #Homecoming  2021.0      90.0   Drama, Musical
# 3                             #Yaaram  2019.0     110.0  Comedy, Romance
# 4                   ...And Once Again  2010.0     105.0            Drama
#
#    Rating   Votes            Director       Actor 1             Actor 2  \
# 0     6.4   604.6       J.S. Randhawa      Manmauji              Birbal
# 1     7.0     8.0       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     6.5  1736.9  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4    35.0          Ovais Khan       Prateik          Ishita Raj
# 4     6.4   604.6        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3            Era Duration_Category Rating_Quantiles
# 0  Rajendra Bhatia  Streaming Era              Long             Good
# 1    Arvind Jangid  Streaming Era            Medium        Excellent
# 2       Roy Angana  Streaming Era            Medium             Good
# 3  Siddhant Kapoor  Streaming Era            Medium             Poor
# 4      Antara Mali  Streaming Era            Medium             Good

# %% [markdown]
# ### Votes

# %%
India_data_cleaned['Votes'].max()
# Out:
# 591417.0

# %%
India_data_cleaned['Votes'].min()
# Out:
# 0.0

# %%
bins = range(0, int(India_data_cleaned['Votes'].max()) + 10000, 10000)  # สร้างช่วงตั้งแต่ 0 ถึงสูงสุดของ 'Votes' ทุก 10,000 โหวต
labels = [f'{i}-{i+10000-1}' for i in bins[:-1]]  # สร้างป้ายกำกับสำหรับแต่ละช่วง

India_data_cleaned['Votes_Range'] = pd.cut(India_data_cleaned['Votes'], bins=bins, labels=labels, include_lowest=True) #include_lowest=True ให้เก็บค่าต่ำสุดด้วย
# Out:
# /tmp/ipython-input-1943059599.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   India_data_cleaned['Votes_Range'] = pd.cut(India_data_cleaned['Votes'], bins=bins, labels=labels, include_lowest=True) #include_lowest=True ให้เก็บค่าต่ำสุดด้วย

# %%
India_data_cleaned['Votes_Range'].unique()
# Out:
# ['0-9999', '20000-29999', '350000-359999', '10000-19999', '70000-79999', ..., '80000-89999', '100000-109999', '590000-599999', '170000-179999', '180000-189999']
# Length: 17
# Categories (60, object): ['0-9999' < '10000-19999' < '20000-29999' < '30000-39999' < ... <
#                           '560000-569999' < '570000-579999' < '580000-589999' < '590000-599999']

# %%
India_data_cleaned.head(5)
# Out:
#                                  Name    Year  Duration            Genre  \
# 0                             "space"  2017.0     120.5            Drama
# 1  #Gadhvi (He thought he was Gandhi)  2019.0     109.0            Drama
# 2                         #Homecoming  2021.0      90.0   Drama, Musical
# 3                             #Yaaram  2019.0     110.0  Comedy, Romance
# 4                   ...And Once Again  2010.0     105.0            Drama
#
#    Rating   Votes            Director       Actor 1             Actor 2  \
# 0     6.4   604.6       J.S. Randhawa      Manmauji              Birbal
# 1     7.0     8.0       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     6.5  1736.9  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4    35.0          Ovais Khan       Prateik          Ishita Raj
# 4     6.4   604.6        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3            Era Duration_Category Rating_Quantiles  \
# 0  Rajendra Bhatia  Streaming Era              Long             Good
# 1    Arvind Jangid  Streaming Era            Medium        Excellent
# 2       Roy Angana  Streaming Era            Medium             Good
# 3  Siddhant Kapoor  Streaming Era            Medium             Poor
# 4      Antara Mali  Streaming Era            Medium             Good
#
#   Votes_Range
# 0      0-9999
# 1      0-9999
# 2      0-9999
# 3      0-9999
# 4      0-9999

# %%
India_data_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11646 entries, 0 to 15508
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               11646 non-null  object
#  1   Year               11646 non-null  float64
#  2   Duration           11646 non-null  float64
#  3   Genre              11646 non-null  object
#  4   Rating             11646 non-null  float64
#  5   Votes              11646 non-null  float64
#  6   Director           11646 non-null  object
#  7   Actor 1            11646 non-null  object
#  8   Actor 2            11646 non-null  object
#  9   Actor 3            11646 non-null  object
#  10  Era                11646 non-null  category
#  11  Duration_Category  11646 non-null  category
#  12  Rating_Quantiles   11646 non-null  category
#  13  Votes_Range        11646 non-null  category
# dtypes: category(4), float64(4), object(6)
# memory usage: 1.0+ MB

# %%
# India_data_cleaned.to_csv('/content/drive/MyDrive/dpdm24_DATA/cleaned_india_data.csv', index=False).to_csv('/content/drive/MyDrive/dpdm24_DATA/cleaned_india_data.csv', index=False)

# %% [markdown]
# ## หา pattern

# %%
import matplotlib.pyplot as plt
numerical_features = ["Year", "Duration", "Rating", "Votes"]
# Create boxplots for each numerical feature
fig, axes = plt.subplots(nrows=1, ncols=len(numerical_features), figsize=(12, 6)) # plot boxplot ของ age,avg_glucose_level,bmi ดูการกระจายของข้อมูล
for i, feature in enumerate(numerical_features):
    axes[i].boxplot(India_data_cleaned[feature])
    axes[i].set_title(feature)
plt.show()

# %%
India_data_cleaned[["Year", "Duration", "Rating", "Votes"]].describe()
# Out:
#                Year      Duration        Rating          Votes
# count  11646.000000  11646.000000  11646.000000   11646.000000
# mean    1990.765488    129.179749      5.804781    1599.731547
# std       22.478731     21.331965      1.161363    9699.050759
# min     1917.000000     21.000000      1.100000       0.000000
# 25%     1975.000000    120.500000      5.100000      29.000000
# 50%     1994.000000    130.000000      5.900000      91.900000
# 75%     2010.000000    140.000000      6.400000     604.600000
# max     2022.000000    321.000000     10.000000  591417.000000

# %% [markdown]
# # เริ่มทำ F

# %%
India_data_cleaned
# Out:
#                                      Name    Year  Duration  \
# 0                                 "space"  2017.0     120.5
# 1      #Gadhvi (He thought he was Gandhi)  2019.0     109.0
# 2                             #Homecoming  2021.0      90.0
# 3                                 #Yaaram  2019.0     110.0
# 4                       ...And Once Again  2010.0     105.0
# ...                                   ...     ...       ...
# 15502                       Zulm Ki Pukar  1979.0     131.0
# 15503                     Zulm Ki Zanjeer  1989.0     125.0
# 15504                 Zulm Ko Jala Doonga  1988.0     131.0
# 15505                               Zulmi  1999.0     129.0
# 15508                        Zulm-O-Sitam  1998.0     130.0
#
#                       Genre  Rating   Votes            Director  \
# 0                     Drama     6.4   604.6       J.S. Randhawa
# 1                     Drama     7.0     8.0       Gaurav Bakshi
# 2            Drama, Musical     6.5  1736.9  Soumyajit Majumdar
# 3           Comedy, Romance     4.4    35.0          Ovais Khan
# 4                     Drama     6.4   604.6        Amol Palekar
# ...                     ...     ...     ...                 ...
# 15502                Action     5.1    44.4     Dinesh-Ramanesh
# 15503  Action, Crime, Drama     5.8    44.0     S.P. Muthuraman
# 15504                Action     4.6    11.0       Mahendra Shah
# 15505         Action, Drama     4.5   655.0          Kuku Kohli
# 15508         Action, Drama     6.2    20.0        K.C. Bokadia
#
#                 Actor 1             Actor 2          Actor 3              Era  \
# 0              Manmauji              Birbal  Rajendra Bhatia    Streaming Era
# 1          Rasika Dugal      Vivek Ghamande    Arvind Jangid    Streaming Era
# 2          Sayani Gupta   Plabita Borthakur       Roy Angana    Streaming Era
# 3               Prateik          Ishita Raj  Siddhant Kapoor    Streaming Era
# 4          Rajat Kapoor  Rituparna Sengupta      Antara Mali    Streaming Era
# ...                 ...                 ...              ...              ...
# 15502       Ramesh Puri          Jalal Agha     Valerie Agha    New Hollywood
# 15503       Chiranjeevi          Jayamalini      Rajinikanth  Blockbuster Era
# 15504  Naseeruddin Shah       Sumeet Saigal    Suparna Anand  Blockbuster Era
# 15505      Akshay Kumar      Twinkle Khanna      Aruna Irani  Blockbuster Era
# 15508        Dharmendra          Jaya Prada      Arjun Sarja  Blockbuster Era
#
#       Duration_Category Rating_Quantiles Votes_Range
# 0                  Long             Good      0-9999
# 1                Medium        Excellent      0-9999
# 2                Medium             Good      0-9999
# 3                Medium             Poor      0-9999
# 4                Medium             Good      0-9999
# ...                 ...              ...         ...
# 15502              Long             Poor      0-9999
# 15503              Long          Average      0-9999
# 15504              Long             Poor      0-9999
# 15505              Long             Poor      0-9999
# 15508              Long          Average      0-9999
#
# [11646 rows x 14 columns]

# %%
# convert categorical variables to numerical using one-hot encoding
cat_vars = ['Genre','Director', 'Actor 1', 'Actor 2', 'Actor 3', 'Era', 'Duration_Category','Rating_Quantiles', 'Votes_Range']  #'Director', 'Actor 1', 'Actor 2', 'Actor 3', 'Era', 'Duration_Category','Rating_Quantiles', 'Votes_Range'
data_encoded = pd.get_dummies(India_data_cleaned, columns=cat_vars)

# %%
data_encoded
# Out:
#                                      Name    Year  Duration  Rating   Votes  \
# 0                                 "space"  2017.0     120.5     6.4   604.6
# 1      #Gadhvi (He thought he was Gandhi)  2019.0     109.0     7.0     8.0
# 2                             #Homecoming  2021.0      90.0     6.5  1736.9
# 3                                 #Yaaram  2019.0     110.0     4.4    35.0
# 4                       ...And Once Again  2010.0     105.0     6.4   604.6
# ...                                   ...     ...       ...     ...     ...
# 15502                       Zulm Ki Pukar  1979.0     131.0     5.1    44.4
# 15503                     Zulm Ki Zanjeer  1989.0     125.0     5.8    44.0
# 15504                 Zulm Ko Jala Doonga  1988.0     131.0     4.6    11.0
# 15505                               Zulmi  1999.0     129.0     4.5   655.0
# 15508                        Zulm-O-Sitam  1998.0     130.0     6.2    20.0
#
#        Genre_Action  Genre_Action, Adventure  \
# 0             False                    False
# 1             False                    False
# 2             False                    False
# 3             False                    False
# 4             False                    False
# ...             ...                      ...
# 15502          True                    False
# 15503         False                    False
# 15504          True                    False
# 15505         False                    False
# 15508         False                    False
#
#        Genre_Action, Adventure, Biography  Genre_Action, Adventure, Comedy  \
# 0                                   False                            False
# 1                                   False                            False
# 2                                   False                            False
# 3                                   False                            False
# 4                                   False                            False
# ...                                   ...                              ...
# 15502                               False                            False
# 15503                               False                            False
# 15504                               False                            False
# 15505                               False                            False
# 15508                               False                            False
#
#        Genre_Action, Adventure, Crime  ...  Votes_Range_500000-509999  \
# 0                               False  ...                      False
# 1                               False  ...                      False
# 2                               False  ...                      False
# 3                               False  ...                      False
# 4                               False  ...                      False
# ...                               ...  ...                        ...
# 15502                           False  ...                      False
# 15503                           False  ...                      False
# 15504                           False  ...                      False
# 15505                           False  ...                      False
# 15508                           False  ...                      False
#
#        Votes_Range_510000-519999  Votes_Range_520000-529999  \
# 0                          False                      False
# 1                          False                      False
# 2                          False                      False
# 3                          False                      False
# 4                          False                      False
# ...                          ...                        ...
# 15502                      False                      False
# 15503                      False                      False
# 15504                      False                      False
# 15505                      False                      False
# 15508                      False                      False
#
#        Votes_Range_530000-539999  Votes_Range_540000-549999  \
# 0                          False                      False
# 1                          False                      False
# 2                          False                      False
# 3                          False                      False
# 4                          False                      False
# ...                          ...                        ...
# 15502                      False                      False
# 15503                      False                      False
# 15504                      False                      False
# 15505                      False                      False
# 15508                      False                      False
#
#        Votes_Range_550000-559999  Votes_Range_560000-569999  \
# 0                          False                      False
# 1                          False                      False
# 2                          False                      False
# 3                          False                      False
# 4                          False                      False
# ...                          ...                        ...
# 15502                      False                      False
# 15503                      False                      False
# 15504                      False                      False
# 15505                      False                      False
# 15508                      False                      False
#
#        Votes_Range_570000-579999  Votes_Range_580000-589999  \
# 0                          False                      False
# 1                          False                      False
# 2                          False                      False
# 3                          False                      False
# 4                          False                      False
# ...                          ...                        ...
# 15502                      False                      False
# 15503                      False                      False
# 15504                      False                      False
# 15505                      False                      False
# 15508                      False                      False
#
#        Votes_Range_590000-599999
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# 4                          False
# ...                          ...
# 15502                      False
# 15503                      False
# 15504                      False
# 15505                      False
# 15508                      False
#
# [11646 rows x 18291 columns]

# %%
data_apri = data_encoded.iloc[:,5:]
data_apri
# Out:
#        Genre_Action  Genre_Action, Adventure  \
# 0             False                    False
# 1             False                    False
# 2             False                    False
# 3             False                    False
# 4             False                    False
# ...             ...                      ...
# 15502          True                    False
# 15503         False                    False
# 15504          True                    False
# 15505         False                    False
# 15508         False                    False
#
#        Genre_Action, Adventure, Biography  Genre_Action, Adventure, Comedy  \
# 0                                   False                            False
# 1                                   False                            False
# 2                                   False                            False
# 3                                   False                            False
# 4                                   False                            False
# ...                                   ...                              ...
# 15502                               False                            False
# 15503                               False                            False
# 15504                               False                            False
# 15505                               False                            False
# 15508                               False                            False
#
#        Genre_Action, Adventure, Crime  Genre_Action, Adventure, Drama  \
# 0                               False                           False
# 1                               False                           False
# 2                               False                           False
# 3                               False                           False
# 4                               False                           False
# ...                               ...                             ...
# 15502                           False                           False
# 15503                           False                           False
# 15504                           False                           False
# 15505                           False                           False
# 15508                           False                           False
#
#        Genre_Action, Adventure, Family  Genre_Action, Adventure, Fantasy  \
# 0                                False                             False
# 1                                False                             False
# 2                                False                             False
# 3                                False                             False
# 4                                False                             False
# ...                                ...                               ...
# 15502                            False                             False
# 15503                            False                             False
# 15504                            False                             False
# 15505                            False                             False
# 15508                            False                             False
#
#        Genre_Action, Adventure, History  Genre_Action, Adventure, Horror  ...  \
# 0                                 False                            False  ...
# 1                                 False                            False  ...
# 2                                 False                            False  ...
# 3                                 False                            False  ...
# 4                                 False                            False  ...
# ...                                 ...                              ...  ...
# 15502                             False                            False  ...
# 15503                             False                            False  ...
# 15504                             False                            False  ...
# 15505                             False                            False  ...
# 15508                             False                            False  ...
#
#        Votes_Range_500000-509999  Votes_Range_510000-519999  \
# 0                          False                      False
# 1                          False                      False
# 2                          False                      False
# 3                          False                      False
# 4                          False                      False
# ...                          ...                        ...
# 15502                      False                      False
# 15503                      False                      False
# 15504                      False                      False
# 15505                      False                      False
# 15508                      False                      False
#
#        Votes_Range_520000-529999  Votes_Range_530000-539999  \
# 0                          False                      False
# 1                          False                      False
# 2                          False                      False
# 3                          False                      False
# 4                          False                      False
# ...                          ...                        ...
# 15502                      False                      False
# 15503                      False                      False
# 15504                      False                      False
# 15505                      False                      False
# 15508                      False                      False
#
#        Votes_Range_540000-549999  Votes_Range_550000-559999  \
# 0                          False                      False
# 1                          False                      False
# 2                          False                      False
# 3                          False                      False
# 4                          False                      False
# ...                          ...                        ...
# 15502                      False                      False
# 15503                      False                      False
# 15504                      False                      False
# 15505                      False                      False
# 15508                      False                      False
#
#        Votes_Range_560000-569999  Votes_Range_570000-579999  \
# 0                          False                      False
# 1                          False                      False
# 2                          False                      False
# 3                          False                      False
# 4                          False                      False
# ...                          ...                        ...
# 15502                      False                      False
# 15503                      False                      False
# 15504                      False                      False
# 15505                      False                      False
# 15508                      False                      False
#
#        Votes_Range_580000-589999  Votes_Range_590000-599999
# 0                          False                      False
# 1                          False                      False
# 2                          False                      False
# 3                          False                      False
# 4                          False                      False
# ...                          ...                        ...
# 15502                      False                      False
# 15503                      False                      False
# 15504                      False                      False
# 15505                      False                      False
# 15508                      False                      False
#
# [11646 rows x 18286 columns]

# %%
apriori(data_apri, min_support=0.05, use_colnames=True)
# Out:
# <generator object apriori at 0x7bd824964ac0>

# %%
data_apri.columns
# Out:
# Index(['Genre_Action', 'Genre_Action, Adventure',
#        'Genre_Action, Adventure, Biography', 'Genre_Action, Adventure, Comedy',
#        'Genre_Action, Adventure, Crime', 'Genre_Action, Adventure, Drama',
#        'Genre_Action, Adventure, Family', 'Genre_Action, Adventure, Fantasy',
#        'Genre_Action, Adventure, History', 'Genre_Action, Adventure, Horror',
#        ...
#        'Votes_Range_500000-509999', 'Votes_Range_510000-519999',
#        'Votes_Range_520000-529999', 'Votes_Range_530000-539999',
#        'Votes_Range_540000-549999', 'Votes_Range_550000-559999',
#        'Votes_Range_560000-569999', 'Votes_Range_570000-579999',
#        'Votes_Range_580000-589999', 'Votes_Range_590000-599999'],
#       dtype='object', length=18286)

# %% [markdown]
# #การวิเคราะห์กฎการเชื่อมโยง: ความสัมพันธ์ระหว่างผู้กำกับ, จำนวนคะแนนโหวต และระดับเรตติ้งของภาพยนตร์

# %%
for col in data_apri.columns:
    if 'Director' in col:
        print(col)
# Out:
# Director_A B Arjun
# Director_A. Bhimsingh
# Director_A. Habib
# Director_A. Jagannathan
# Director_A. Karim
# Director_A. Kodandarami Reddy
# Director_A. Majid
# Director_A. Muthu
# Director_A. Raja
# Director_A. Rashid
# Director_A. Salaam
# Director_A. Shakoor
# Director_A. Shamsheer
# Director_A. Veerappan
# Director_A. Venkatesh
# Director_A. Zahoor
# Director_A.A. Darpan
# Director_A.C. Trilogchander
# Director_A.G. Surma
# Director_A.H. Essa
# Director_A.K. Bir
# Director_A.K. Hangal
# Director_A.K. Mishra
# Director_A.L. Vijay
# Director_A.M. Khan
# Director_A.M.R. Ramesh
# Director_A.N. Bannerjee
# Director_A.P. Nagarajan
# Director_A.P. Subbaraav
# Director_A.R. Kabuli
# Director_A.R. Murugadoss
# Director_A.R. Zamindar
# Director_A.S. Arora
# Director_A.T. Joy
# Director_A.T. Raghu
# Director_Aadesh Vishwakarma
# Director_Aadish Keluskar
# Director_Aakash Bhatia
# Director_Aakash Gupta
# Director_Aakkoo
# Director_Aamir Bashir
# Director_Aamir Khan
# Director_Aamreeta Gautam
# Director_Aanand L. Rai
# Director_Aanand Raut
# Director_Aanchal Malhotra
# Director_Aarif Sheikh
# Director_Aarti S. Bagdi
# Director_Aarun Nagar
# Director_Aaryaan Saxena
# Director_Aashish Chanana
# Director_Aashish Sinha
# Director_Aashnee
# Director_Aatish Kapadia
# Director_Aban Bharucha Deohans
# Director_Abbas
# Director_Abbas Alibhai Burmawalla
# Director_Abbas Tyrewala
# Director_Abdul Qayyoom Khan
# Director_Abdul Rashid Kardar
# Director_Abdul Sattar
# Director_Abdul Sattar Khan
# Director_Abhay Chhabra
# Director_Abhay Chopra
# Director_Abhi Bhattacharya
# Director_Abhigyan Jha
# Director_Abhijeet Choudhary
# Director_Abhijeet Kumar
# Director_Abhijeet More
# Director_Abhijeet Sahoo
# Director_Abhijeet Warang
#  'Votes_Range_70000-79999',
#  'Votes_Range_80000-89999',
#  'Votes_Range_90000-99999']

# %%
[col for col in data_apri.columns if col.startswith('Rating_Quantiles')]
# Out:
# ['Rating_Quantiles_Poor',
#  'Rating_Quantiles_Below Average',
#  'Rating_Quantiles_Average',
#  'Rating_Quantiles_Good',
#  'Rating_Quantiles_Excellent']

# %% [markdown]
# ##เลือกเฉพาะ columns ที่สนใจ

# %%
selected_columns = [col for col in data_apri.columns if col.startswith('Director')] + \
                    [col for col in data_apri.columns if col.startswith('Votes_Range')] + \
                     [col for col in data_apri.columns if col.startswith('Rating_Quantiles')]

# %%
len(selected_columns)
# Out:
# 4812

# %%
data_selected = data_apri[selected_columns]
data_selected.shape
# Out:
# (11646, 4812)

# %%
data_selected.head()
# Out:
#    Director_A B Arjun  Director_A. Bhimsingh  Director_A. Habib  \
# 0               False                  False              False
# 1               False                  False              False
# 2               False                  False              False
# 3               False                  False              False
# 4               False                  False              False
#
#    Director_A. Jagannathan  Director_A. Karim  Director_A. Kodandarami Reddy  \
# 0                    False              False                          False
# 1                    False              False                          False
# 2                    False              False                          False
# 3                    False              False                          False
# 4                    False              False                          False
#
#    Director_A. Majid  Director_A. Muthu  Director_A. Raja  Director_A. Rashid  \
# 0              False              False             False               False
# 1              False              False             False               False
# 2              False              False             False               False
# 3              False              False             False               False
# 4              False              False             False               False
#
#    ...  Votes_Range_550000-559999  Votes_Range_560000-569999  \
# 0  ...                      False                      False
# 1  ...                      False                      False
# 2  ...                      False                      False
# 3  ...                      False                      False
# 4  ...                      False                      False
#
#    Votes_Range_570000-579999  Votes_Range_580000-589999  \
# 0                      False                      False
# 1                      False                      False
# 2                      False                      False
# 3                      False                      False
# 4                      False                      False
#
#    Votes_Range_590000-599999  Rating_Quantiles_Poor  \
# 0                      False                  False
# 1                      False                  False
# 2                      False                  False
# 3                      False                   True
# 4                      False                  False
#
#    Rating_Quantiles_Below Average  Rating_Quantiles_Average  \
# 0                           False                     False
# 1                           False                     False
# 2                           False                     False
# 3                           False                     False
# 4                           False                     False
#
#    Rating_Quantiles_Good  Rating_Quantiles_Excellent
# 0                   True                       False
# 1                  False                        True
# 2                   True                       False
# 3                  False                       False
# 4                   True                       False
#
# [5 rows x 4812 columns]

# %% [markdown]
# ### Run Apriori

# %%
from mlxtend.frequent_patterns import apriori, association_rules

# ค่าที่ตั้งต้น
min_sup = 0.001

# คำนวณ frequent itemsets
frequentItemsets = apriori(data_selected, min_support=min_sup, use_colnames=True)

# สร้างกฎเชื่อมโยง (association rules) จาก frequent itemsets
rules = association_rules(frequentItemsets, metric="lift", min_threshold=1)
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
rules
# Out:
#                                         antecedents  \
# 0                           (Director_A. Bhimsingh)
# 1                              (Votes_Range_0-9999)
# 2                              (Director_A. Salaam)
# 3                              (Votes_Range_0-9999)
# 4                           (Director_A. Shamsheer)
# ..                                              ...
# 579  (Director_Vikram Bhatt, Rating_Quantiles_Poor)
# 580     (Votes_Range_0-9999, Rating_Quantiles_Poor)
# 581                         (Director_Vikram Bhatt)
# 582                            (Votes_Range_0-9999)
# 583                         (Rating_Quantiles_Poor)
#
#                                         consequents  antecedent support  \
# 0                              (Votes_Range_0-9999)            0.001460
# 1                           (Director_A. Bhimsingh)            0.968229
# 2                              (Votes_Range_0-9999)            0.001030
# 3                              (Director_A. Salaam)            0.968229
# 4                              (Votes_Range_0-9999)            0.001717
# ..                                              ...                 ...
# 579                            (Votes_Range_0-9999)            0.001803
# 580                         (Director_Vikram Bhatt)            0.270908
# 581     (Votes_Range_0-9999, Rating_Quantiles_Poor)            0.002834
# 582  (Director_Vikram Bhatt, Rating_Quantiles_Poor)            0.968229
# 583     (Director_Vikram Bhatt, Votes_Range_0-9999)            0.273313
#
#      consequent support   support  confidence      lift  representativity  \
# 0              0.968229  0.001460    1.000000  1.032813               1.0
# 1              0.001460  0.001460    0.001508  1.032813               1.0
# 2              0.968229  0.001030    1.000000  1.032813               1.0
# 3              0.001030  0.001030    0.001064  1.032813               1.0
# 4              0.968229  0.001717    1.000000  1.032813               1.0
# ..                  ...       ...         ...       ...               ...
# 579            0.968229  0.001803    1.000000  1.032813               1.0
# 580            0.002834  0.001803    0.006656  2.348999               1.0
# 581            0.270908  0.001803    0.636364  2.348999               1.0
# 582            0.001803  0.001803    0.001862  1.032813               1.0
# 583            0.002748  0.001803    0.006598  2.401096               1.0
#
#      leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 0    0.000046         inf       0.031817  0.001508   1.000000    0.500754
# 1    0.000046    1.000048       1.000000  0.001508   0.000048    0.500754
# 2    0.000033         inf       0.031803  0.001064   1.000000    0.500532
# 3    0.000033    1.000034       1.000000  0.001064   0.000034    0.500532
# 4    0.000055         inf       0.031825  0.001774   1.000000    0.500887
# ..        ...         ...            ...       ...        ...         ...
# 579  0.000057         inf       0.031828  0.001862   1.000000    0.500931
# 580  0.001036    1.003848       0.787674  0.006631   0.003833    0.321510
# 581  0.001036    2.005002       0.575919  0.006631   0.501247    0.321510
# 582  0.000057    1.000059       1.000000  0.001862   0.000059    0.500931
# 583  0.001052    1.003875       0.802991  0.006575   0.003860    0.331424
#
# [584 rows x 14 columns]

# %%
rules[rules["antecedents"].astype(str).str.contains("Director") & rules["antecedents"].astype(str).str.contains("Votes_Range")]
# Out:
#                                            antecedents  \
# 374        (Votes_Range_0-9999, Director_Ajay Kashyap)
# 380         (Director_B.R. Chopra, Votes_Range_0-9999)
# 386         (Director_B.R. Ishara, Votes_Range_0-9999)
# 392         (Director_B.R. Ishara, Votes_Range_0-9999)
# 398     (Director_Babubhai Mistry, Votes_Range_0-9999)
# 404     (Director_Basu Chatterjee, Votes_Range_0-9999)
# 411           (Votes_Range_0-9999, Director_Bimal Roy)
# 417        (Votes_Range_0-9999, Director_Chetan Anand)
# 422        (Director_David Dhawan, Votes_Range_0-9999)
# 426        (Votes_Range_0-9999, Director_Deepak Bahry)
# 432    (Votes_Range_0-9999, Director_Dinesh Chaudhary)
# 438              (Director_Gulzar, Votes_Range_0-9999)
# 444    (Votes_Range_0-9999, Director_Harmesh Malhotra)
# 450  (Director_Hrishikesh Mukherjee, Votes_Range_0-...
# 454          (Votes_Range_0-9999, Director_K. Bapaiah)
# 460        (Votes_Range_0-9999, Director_K.C. Bokadia)
# 466          (Director_Kanti Shah, Votes_Range_0-9999)
# 472         (Director_Kishan Shah, Votes_Range_0-9999)
# 478        (Director_Mahesh Bhatt, Votes_Range_0-9999)
# 482        (Director_Mahesh Bhatt, Votes_Range_0-9999)
# 488    (Director_Mohammed Hussain, Votes_Range_0-9999)
# 494      (Director_Nanabhai Bhatt, Votes_Range_0-9999)
# 500        (Director_Partho Ghosh, Votes_Range_0-9999)
# 506          (Director_Raj Khosla, Votes_Range_0-9999)
# 512        (Director_Raj N. Sippy, Votes_Range_0-9999)
# 518     (Votes_Range_0-9999, Director_Ram Gopal Varma)
# 524   (Votes_Range_0-9999, Director_Rama Rao Tatineni)
# 530         (Director_Satyen Bose, Votes_Range_0-9999)
# 537      (Votes_Range_0-9999, Director_Shakti Samanta)
# 542      (Director_Shantilal Soni, Votes_Range_0-9999)
# 549         (Votes_Range_0-9999, Director_Shibu Mitra)
# 555         (Votes_Range_0-9999, Director_Shibu Mitra)
# 561       (Votes_Range_0-9999, Director_Shyam Benegal)
# 566       (Votes_Range_0-9999, Director_T.L.V. Prasad)
# 572         (Director_Vijay Anand, Votes_Range_0-9999)
# 578        (Director_Vikram Bhatt, Votes_Range_0-9999)
#
#                       consequents  antecedent support  consequent support  \
# 374       (Rating_Quantiles_Poor)            0.001374            0.273313
# 380  (Rating_Quantiles_Excellent)            0.001460            0.183840
# 386    (Rating_Quantiles_Average)            0.003435            0.231839
# 392       (Rating_Quantiles_Good)            0.003435            0.179547
# 398    (Rating_Quantiles_Average)            0.003606            0.231839
# 404  (Rating_Quantiles_Excellent)            0.003005            0.183840
# 411  (Rating_Quantiles_Excellent)            0.001374            0.183840
# 417  (Rating_Quantiles_Excellent)            0.001546            0.183840
# 422       (Rating_Quantiles_Poor)            0.003435            0.273313
# 426       (Rating_Quantiles_Poor)            0.001717            0.273313
# 432    (Rating_Quantiles_Average)            0.002318            0.231839
# 438  (Rating_Quantiles_Excellent)            0.001460            0.183840
# 444       (Rating_Quantiles_Poor)            0.002490            0.273313
# 450  (Rating_Quantiles_Excellent)            0.003349            0.183840
# 454       (Rating_Quantiles_Poor)            0.002662            0.273313
# 460       (Rating_Quantiles_Poor)            0.001546            0.273313
# 466       (Rating_Quantiles_Poor)            0.004293            0.273313
# 472       (Rating_Quantiles_Poor)            0.002834            0.273313
# 478       (Rating_Quantiles_Poor)            0.003864            0.273313
# 482    (Rating_Quantiles_Average)            0.003864            0.231839
# 488    (Rating_Quantiles_Average)            0.002834            0.231839
# 494    (Rating_Quantiles_Average)            0.002834            0.231839
# 500       (Rating_Quantiles_Poor)            0.001975            0.273313
# 506  (Rating_Quantiles_Excellent)            0.002233            0.183840
# 512       (Rating_Quantiles_Poor)            0.002834            0.273313
# 518       (Rating_Quantiles_Poor)            0.002748            0.273313
# 524       (Rating_Quantiles_Poor)            0.003005            0.273313
# 530  (Rating_Quantiles_Excellent)            0.002404            0.183840
# 537  (Rating_Quantiles_Excellent)            0.003263            0.183840
# 542    (Rating_Quantiles_Average)            0.001803            0.231839
# 549       (Rating_Quantiles_Poor)            0.003005            0.273313
# 417       0.780599  0.006996   0.795792    0.420170
# 422       0.481057  0.006558   0.346349    0.265799
# 426       0.545415  0.003761   0.449557    0.301885
# 432       0.633253  0.006273   0.517848    0.317963
# 438       0.777901  0.006530   0.783779    0.415034
# 444       0.340342  0.003750   0.193316    0.208782
# 450       0.715606  0.011601   0.560167    0.326351
# 454       0.436315  0.004689   0.289751    0.244292
# 460       0.622529  0.004078   0.617748    0.363153
# 466       0.531051  0.009051   0.422035    0.294555
# 472       0.572130  0.006573   0.499597    0.321481
# 478       0.180760  0.004669   0.082595    0.169023
# 482       0.198246  0.004758   0.074268    0.146852
# 488       0.491346  0.005519   0.289921    0.230051
# 494       0.412654  0.004779   0.211024    0.199377
# 500       0.477093  0.003757   0.341862    0.262755
# 506       0.603026  0.005568   0.340250    0.233572
# 512       0.470786  0.005314   0.332796    0.260246
# 518       0.328132  0.004060   0.182936    0.205167
# 524       0.317673  0.004370   0.174335    0.202199
# 530       0.605493  0.006030   0.343616    0.235179
# 537       0.634390  0.008796   0.387375    0.254437
# 542       0.626620  0.004801   0.504072    0.311931
# 549       0.317673  0.004370   0.174335    0.202199
# 555       0.324778  0.004407   0.144524    0.173651
# 561       0.766607  0.008388   0.733641    0.395508
# 566       0.611128  0.006579   0.587168    0.353299
# 572       0.740641  0.005592   0.639632    0.355744
# 578       0.585131  0.006575   0.526963    0.331424

# %%
rules[rules["antecedents"].astype(str).str.contains("Director") &
      rules["antecedents"].astype(str).str.contains("Votes_Range") &
      (rules["lift"] >= 3)]
# Out:
#                                            antecedents  \
# 380         (Director_B.R. Chopra, Votes_Range_0-9999)
# 411           (Votes_Range_0-9999, Director_Bimal Roy)
# 417        (Votes_Range_0-9999, Director_Chetan Anand)
# 438              (Director_Gulzar, Votes_Range_0-9999)
# 450  (Director_Hrishikesh Mukherjee, Votes_Range_0-...
# 561       (Votes_Range_0-9999, Director_Shyam Benegal)
# 572         (Director_Vijay Anand, Votes_Range_0-9999)
#
#                       consequents  antecedent support  consequent support  \
# 380  (Rating_Quantiles_Excellent)            0.001460             0.18384
# 411  (Rating_Quantiles_Excellent)            0.001374             0.18384
# 417  (Rating_Quantiles_Excellent)            0.001546             0.18384
# 438  (Rating_Quantiles_Excellent)            0.001460             0.18384
# 450  (Rating_Quantiles_Excellent)            0.003349             0.18384
# 561  (Rating_Quantiles_Excellent)            0.001975             0.18384
# 572  (Rating_Quantiles_Excellent)            0.001460             0.18384
#
#       support  confidence      lift  representativity  leverage  conviction  \
# 380  0.001030    0.705882  3.839657               1.0  0.000762    2.774944
# 411  0.001116    0.812500  4.419605               1.0  0.000864    4.352854
# 417  0.001288    0.833333  4.532929               1.0  0.001004    4.896960
# 438  0.001202    0.823529  4.479600               1.0  0.000934    4.624907
# 450  0.002147    0.641026  3.486868               1.0  0.001531    2.273589
# 561  0.001546    0.782609  4.257011               1.0  0.001183    3.754336
# 572  0.001030    0.705882  3.839657               1.0  0.000762    2.774944
#
#      zhangs_metric   jaccard  certainty  kulczynski
# 380       0.740641  0.005592   0.639632    0.355744
# 411       0.774800  0.006063   0.770266    0.409286
# 417       0.780599  0.006996   0.795792    0.420170
# 438       0.777901  0.006530   0.783779    0.415034
# 450       0.715606  0.011601   0.560167    0.326351
# 561       0.766607  0.008388   0.733641    0.395508
# 572       0.740641  0.005592   0.639632    0.355744

# %% [markdown]
# กฎนี้แสดงให้เห็นว่า สำหรับผู้กำกับ B.R. Chopra ภาพยนตร์ของเขาที่ได้รับคะแนนโหวตไม่มากนัก (0-9999 โหวต) มีโอกาสสูงมาก (ประมาณ 70.6%) ที่จะได้เรตติ้งในระดับ 'Excellent' (ยอดเยี่ยม) ความสัมพันธ์นี้มีความแข็งแกร่งอย่างมีนัยสำคัญ ซึ่งบ่งชี้ว่าแม้ภาพยนตร์ของเขาจะไม่ได้มีคนโหวตจำนวนมาก แต่คุณภาพของภาพยนตร์ก็ได้รับการยอมรับในระดับสูงมากจากกลุ่มผู้ชมที่โหวตให้

# %%
rules[rules["antecedents"].astype(str).str.contains("Director") & \
      rules["antecedents"].astype(str).str.contains("Votes_Range_0-9999")]
# Out:
#                                            antecedents  \
# 374        (Votes_Range_0-9999, Director_Ajay Kashyap)
# 380         (Director_B.R. Chopra, Votes_Range_0-9999)
# 386         (Director_B.R. Ishara, Votes_Range_0-9999)
# 392         (Director_B.R. Ishara, Votes_Range_0-9999)
# 398     (Director_Babubhai Mistry, Votes_Range_0-9999)
# 404     (Director_Basu Chatterjee, Votes_Range_0-9999)
# 411           (Votes_Range_0-9999, Director_Bimal Roy)
# 417        (Votes_Range_0-9999, Director_Chetan Anand)
# 422        (Director_David Dhawan, Votes_Range_0-9999)
# 426        (Votes_Range_0-9999, Director_Deepak Bahry)
# 432    (Votes_Range_0-9999, Director_Dinesh Chaudhary)
# 438              (Director_Gulzar, Votes_Range_0-9999)
# 444    (Votes_Range_0-9999, Director_Harmesh Malhotra)
# 450  (Director_Hrishikesh Mukherjee, Votes_Range_0-...
# 454          (Votes_Range_0-9999, Director_K. Bapaiah)
# 460        (Votes_Range_0-9999, Director_K.C. Bokadia)
# 466          (Director_Kanti Shah, Votes_Range_0-9999)
# 472         (Director_Kishan Shah, Votes_Range_0-9999)
# 478        (Director_Mahesh Bhatt, Votes_Range_0-9999)
# 482        (Director_Mahesh Bhatt, Votes_Range_0-9999)
# 488    (Director_Mohammed Hussain, Votes_Range_0-9999)
# 494      (Director_Nanabhai Bhatt, Votes_Range_0-9999)
# 500        (Director_Partho Ghosh, Votes_Range_0-9999)
# 506          (Director_Raj Khosla, Votes_Range_0-9999)
# 512        (Director_Raj N. Sippy, Votes_Range_0-9999)
# 518     (Votes_Range_0-9999, Director_Ram Gopal Varma)
# 524   (Votes_Range_0-9999, Director_Rama Rao Tatineni)
# 530         (Director_Satyen Bose, Votes_Range_0-9999)
# 537      (Votes_Range_0-9999, Director_Shakti Samanta)
# 542      (Director_Shantilal Soni, Votes_Range_0-9999)
# 549         (Votes_Range_0-9999, Director_Shibu Mitra)
# 555         (Votes_Range_0-9999, Director_Shibu Mitra)
# 561       (Votes_Range_0-9999, Director_Shyam Benegal)
# 566       (Votes_Range_0-9999, Director_T.L.V. Prasad)
# 572         (Director_Vijay Anand, Votes_Range_0-9999)
# 578        (Director_Vikram Bhatt, Votes_Range_0-9999)
#
#                       consequents  antecedent support  consequent support  \
# 374       (Rating_Quantiles_Poor)            0.001374            0.273313
# 380  (Rating_Quantiles_Excellent)            0.001460            0.183840
# 386    (Rating_Quantiles_Average)            0.003435            0.231839
# 392       (Rating_Quantiles_Good)            0.003435            0.179547
# 398    (Rating_Quantiles_Average)            0.003606            0.231839
# 404  (Rating_Quantiles_Excellent)            0.003005            0.183840
# 411  (Rating_Quantiles_Excellent)            0.001374            0.183840
# 417  (Rating_Quantiles_Excellent)            0.001546            0.183840
# 422       (Rating_Quantiles_Poor)            0.003435            0.273313
# 426       (Rating_Quantiles_Poor)            0.001717            0.273313
# 432    (Rating_Quantiles_Average)            0.002318            0.231839
# 438  (Rating_Quantiles_Excellent)            0.001460            0.183840
# 444       (Rating_Quantiles_Poor)            0.002490            0.273313
# 450  (Rating_Quantiles_Excellent)            0.003349            0.183840
# 454       (Rating_Quantiles_Poor)            0.002662            0.273313
# 460       (Rating_Quantiles_Poor)            0.001546            0.273313
# 466       (Rating_Quantiles_Poor)            0.004293            0.273313
# 472       (Rating_Quantiles_Poor)            0.002834            0.273313
# 478       (Rating_Quantiles_Poor)            0.003864            0.273313
# 482    (Rating_Quantiles_Average)            0.003864            0.231839
# 488    (Rating_Quantiles_Average)            0.002834            0.231839
# 494    (Rating_Quantiles_Average)            0.002834            0.231839
# 500       (Rating_Quantiles_Poor)            0.001975            0.273313
# 506  (Rating_Quantiles_Excellent)            0.002233            0.183840
# 512       (Rating_Quantiles_Poor)            0.002834            0.273313
# 518       (Rating_Quantiles_Poor)            0.002748            0.273313
# 524       (Rating_Quantiles_Poor)            0.003005            0.273313
# 530  (Rating_Quantiles_Excellent)            0.002404            0.183840
# 537  (Rating_Quantiles_Excellent)            0.003263            0.183840
# 542    (Rating_Quantiles_Average)            0.001803            0.231839
# 549       (Rating_Quantiles_Poor)            0.003005            0.273313
# 555    (Rating_Quantiles_Average)            0.003005            0.231839
# 561  (Rating_Quantiles_Excellent)            0.001975            0.183840
# 566       (Rating_Quantiles_Poor)            0.002576            0.273313
# 572  (Rating_Quantiles_Excellent)            0.001460            0.183840
# 578       (Rating_Quantiles_Poor)            0.002748            0.273313
#
#       support  confidence      lift  representativity  leverage  conviction  \
# 374  0.001116    0.812500  2.972785               1.0  0.000741    3.875665
# 380  0.001030    0.705882  3.839657               1.0  0.000762    2.774944
# 386  0.001030    0.300000  1.294000               1.0  0.000234    1.097372
# 392  0.001460    0.425000  2.367073               1.0  0.000843    1.426875
# 398  0.001717    0.476190  2.053968               1.0  0.000881    1.466489
# 404  0.001546    0.514286  2.797464               1.0  0.000993    1.680330
# 411  0.001116    0.812500  4.419605               1.0  0.000864    4.352854
# 417  0.001288    0.833333  4.532929               1.0  0.001004    4.896960
# 422  0.001803    0.525000  1.920877               1.0  0.000864    1.529868
# 426  0.001030    0.600000  2.195287               1.0  0.000561    1.816718
# 530       0.605493  0.006030   0.343616    0.235179
# 537       0.634390  0.008796   0.387375    0.254437
# 542       0.626620  0.004801   0.504072    0.311931
# 549       0.317673  0.004370   0.174335    0.202199
# 555       0.324778  0.004407   0.144524    0.173651
# 561       0.766607  0.008388   0.733641    0.395508
# 566       0.611128  0.006579   0.587168    0.353299
# 572       0.740641  0.005592   0.639632    0.355744
# 578       0.585131  0.006575   0.526963    0.331424

# %% [markdown]
# **หัวข้อ: "การวิเคราะห์กฎการเชื่อมโยง: ความสัมพันธ์ระหว่างผู้กำกับ, จำนวนคะแนนโหวต และระดับเรตติ้งของภาพยนตร์"**
#
# **วัตถุประสงค์:** "เพื่อระบุและทำความเข้าใจรูปแบบและความสัมพันธ์ที่น่าสนใจระหว่างผู้กำกับ, จำนวนคะแนนโหวต และระดับเรตติ้งของภาพยนตร์ โดยใช้เทคนิค Apriori Algorithm เพื่อค้นหาปัจจัยที่มีอิทธิพลร่วมกันต่อผลงานของภาพยนตร์"
#
#
#
# **ทำไมถึงอยากทำหัวข้อนี้ (Motivation):**
#
# * ค้นหารูปแบบที่ซ่อนอยู่: ข้อมูลภาพยนตร์มักมีมิติที่ซับซ้อน การดูแค่ค่าเฉลี่ยหรือสถิติพื้นฐานอาจไม่เพียงพอ การวิเคราะห์กฎการเชื่อมโยงช่วยให้เราค้นพบความสัมพันธ์เชิงลึกระหว่างตัวแปรต่าง ๆ เช่น ผู้กำกับคนนี้มักจะทำหนังที่ได้เรตติ้งดีเยี่ยมเสมอ แม้จะมีคนโหวตไม่มากนัก
# * เข้าใจอิทธิพลของผู้กำกับ: ต้องการทำความเข้าใจว่าชื่อของผู้กำกับมีความเชื่อมโยงโดยตรงกับผลตอบรับ (ทั้งจากคะแนนโหวตและเรตติ้ง) ของภาพยนตร์อย่างไร โดยเฉพาะในกรณีที่มีคะแนนโหวตไม่สูงมาก ซึ่งอาจสะท้อนถึงกลุ่มผู้ชมเฉพาะหรือคุณภาพที่ไม่เป็นที่รู้จักในวงกว้าง
# นอกเหนือจากการวิเคราะห์เดี่ยว: แทนที่จะวิเคราะห์ผู้กำกับ, คะแนนโหวต หรือเรตติ้งแยกกัน การวิเคราะห์นี้ช่วยให้เราเห็นความสัมพันธ์ที่เกิดขึ้นพร้อมกันระหว่างหลายปัจจัย
#
# **ทำแล้วได้อะไร (Benefits):**
#
# * ข้อมูลเชิงลึกสำหรับอุตสาหกรรมภาพยนตร์:
# ผู้สร้างภาพยนตร์/สตูดิโอ: สามารถใช้ข้อมูลนี้ในการตัดสินใจเลือกผู้กำกับสำหรับโครงการต่าง ๆ โดยพิจารณาจากแนวโน้มเรตติ้งที่ผู้กำกับคนนั้นมักจะได้รับ
# การตลาด: ช่วยในการวางแผนกลยุทธ์การตลาด โดยอาจเน้นไปที่กลุ่มเป้าหมายที่ชื่นชอบผลงานของผู้กำกับบางราย หรือโปรโมทภาพยนตร์ที่มีศักยภาพในการได้เรตติ้งสูงจากผู้กำกับที่มีชื่อเสียง
# * ปรับปรุงระบบแนะนำภาพยนตร์:
# ระบบแนะนำสามารถใช้กฎเหล่านี้เพื่อแนะนำภาพยนตร์ให้ผู้ชมได้แม่นยำยิ่งขึ้น เช่น หากผู้ชมชอบภาพยนตร์ที่มีเรตติ้ง 'Excellent' จากผู้กำกับบางคน ระบบสามารถแนะนำภาพยนตร์อื่น ๆ จากผู้กำกับคนเดียวกันที่มีแนวโน้มจะได้รับเรตติ้ง 'Excellent' แม้จะมีจำนวนโหวตน้อยก็ตาม
# ทำความเข้าใจคุณค่าที่แท้จริงของภาพยนตร์: การที่ภาพยนตร์มีเรตติ้ง 'Excellent' แม้จะมีคะแนนโหวตต่ำ อาจบ่งบอกถึงภาพยนตร์ที่มีคุณภาพสูงแต่ยังไม่เป็นที่รู้จักในวงกว้าง ซึ่งมีคุณค่าในการค้นพบ
# * การระบุ 'แบรนด์' ของผู้กำกับ: ช่วยให้เห็นว่าผู้กำกับคนใดมี 'แบรนด์' ที่แข็งแกร่งในการสร้างภาพยนตร์ที่มีคุณภาพสอดคล้องกับเรตติ้งในระดับใดระดับหนึ่งอย่างต่อเนื่อง

# %% [markdown]
# # test

# %%
explanation = """
antecedents: นี่คือรายการของไอเท็มที่อยู่ทางซ้ายมือของกฎการเชื่อมโยง (IF part of the rule). หมายถึงไอเท็มที่ซื้อก่อนหรือเป็นเงื่อนไขที่นำไปสู่การซื้อไอเท็มอื่น ๆ
consequents: นี่คือรายการของไอเท็มที่อยู่ทางขวามือของกฎการเชื่อมโยง (THEN part of the rule). หมายถึงไอเท็มที่ถูกซื้อหลังจากที่ไอเท็มใน antecedents ถูกซื้อไปแล้ว
antecedent support: คือค่า Support ของ Antecedent (โอกาสที่รายการไอเท็มใน Antecedent จะเกิดขึ้นใน Transaction ทั้งหมด)
consequent support: คือค่า Support ของ Consequent (โอกาสที่รายการไอเท็มใน Consequent จะเกิดขึ้นใน Transaction ทั้งหมด)
support: คือค่า Support ของทั้ง Antecedent และ Consequent ร่วมกัน (โอกาสที่ทั้งสองรายการไอเท็มจะเกิดขึ้นพร้อมกันใน Transaction ทั้งหมด) สูตร: support(A U B) = (จำนวน Transaction ที่มี A และ B) / (จำนวน Transaction ทั้งหมด)
confidence: คือค่าความน่าจะเป็นที่ว่า ถ้าซื้อไอเท็มใน Antecedent แล้วจะซื้อไอเท็มใน Consequent ด้วย สูตร: confidence(A -> B) = support(A U B) / support(A)
lift: คือค่าที่ใช้วัดว่าไอเท็มใน Antecedent และ Consequent มีความเกี่ยวข้องกันมากน้อยเพียงใด ถ้า lift > 1 แสดงว่ามีความเกี่ยวข้องกันในทางบวก (ซื้อ A แล้วมีแนวโน้มจะซื้อ B มากขึ้น), ถ้า lift < 1 แสดงว่ามีความเกี่ยวข้องกันในทางลบ, ถ้า lift = 1 แสดงว่าไม่มีความเกี่ยวข้องกัน สูตร: lift(A -> B) = confidence(A -> B) / support(B)
representativity: มักจะไม่เป็นมาตรฐานใน library ทั่วไป แต่ใน mlxtend มักจะถูกคำนวณเป็น 1.0 เสมอเมื่อใช้ร่วมกับ metric อื่นๆ หรืออาจบ่งบอกถึงว่ากฎนี้เป็นตัวแทนที่ดีของข้อมูลหรือไม่ (อย่างไรก็ตามใน mlxtend มักจะเป็น 1.0 สำหรับกฎที่ผ่านเกณฑ์เบื้องต้น)
leverage: คล้ายกับ lift แต่ตีความต่างกันเล็กน้อย leverage = support(A U B) - (support(A) * support(B)) ถ้า leverage > 0 หมายถึง A และ B ปรากฏพร้อมกันบ่อยกว่าที่คาดไว้โดยบังเอิญ
conviction: เป็นการวัดว่า antecedent (IF) มีผลต่อ consequent (THEN) มากน้อยเพียงใด โดยไม่คำนึงถึงว่าไอเท็มนั้นจะถูกซื้อบ่อยแค่ไหน สูตร: conviction(A -> B) = (1 - support(B)) / (1 - confidence(A -> B)) ค่าสูงหมายถึงความสัมพันธ์ที่แข็งแกร่ง
zhangs_metric: เป็นอีกหนึ่งตัววัดความแข็งแกร่งของกฎการเชื่อมโยงที่คำนึงถึงทั้ง support และ confidence มันสามารถบอกทิศทางและความแข็งแกร่งของความสัมพันธ์ได้ โดยค่าอยู่ระหว่าง -1 ถึง 1
jaccard: คือการวัดความคล้ายคลึงกันระหว่างชุดไอเท็มใน Antecedent และ Consequent สูตร: Jaccard(A, B) = support(A U B) / (support(A) + support(B) - support(A U B))
certanity: คือการวัดว่า Antecedent นำไปสู่ Consequent อย่างแน่นอนแค่ไหน โดยคำนึงถึงความถี่ของ Consequent สูตร: Certainty(A -> B) = (confidence(A -> B) - support(B)) / (1 - support(B))
kulczynski: เป็นค่าเฉลี่ยของความเชื่อมั่นทั้งสองทิศทาง (A -> B และ B -> A) เพื่อให้เห็นความสัมพันธ์โดยรวมระหว่างไอเท็ม สูตร: Kulczynski(A, B) = 0.5 * (confidence(A -> B) + confidence(B -> A))
"""

# print(explanation) # Uncomment to print the explanation

# %%
rules[rules["antecedents"].astype(str).str.contains("Director")]
# Out:
#                                        antecedents  \
# 0                          (Director_Ajay Kashyap)
# 3                           (Director_B.R. Chopra)
# 4                           (Director_B.R. Ishara)
# 6                           (Director_B.R. Ishara)
# 8                           (Director_B.R. Ishara)
# 10                      (Director_Babubhai Mistry)
# 13                      (Director_Basu Chatterjee)
# 14                            (Director_Bimal Roy)
# 17                         (Director_Chetan Anand)
# 19                         (Director_David Dhawan)
# 20                         (Director_Deepak Bahry)
# 23                     (Director_Dinesh Chaudhary)
# 25                               (Director_Gulzar)
# 27                     (Director_Harmesh Malhotra)
# 29                 (Director_Hrishikesh Mukherjee)
# 30                           (Director_K. Bapaiah)
# 33                         (Director_K.C. Bokadia)
# 35                           (Director_Kanti Shah)
# 36                           (Director_Kanti Shah)
# 39                          (Director_Kishan Shah)
# 40                          (Director_Kishan Shah)
# 43                (Director_Kodanda Rami Reddy A.)
# 45                         (Director_Mahesh Bhatt)
# 47                         (Director_Mahesh Bhatt)
# 49                         (Director_Mahesh Bhatt)
# 51                     (Director_Mohammed Hussain)
# 53                     (Director_Mohammed Hussain)
# 54                       (Director_Nanabhai Bhatt)
# 57                         (Director_Partho Ghosh)
# 59                         (Director_Priyadarshan)
# 61                           (Director_Raj Khosla)
# 63                         (Director_Raj N. Sippy)
# 64                      (Director_Ram Gopal Varma)
# 67                    (Director_Rama Rao Tatineni)
# 69                          (Director_Satyen Bose)
# 71                       (Director_Shakti Samanta)
# 72                       (Director_Shantilal Soni)
# 75                          (Director_Shibu Mitra)
# 77                          (Director_Shibu Mitra)
# 79                        (Director_Shyam Benegal)
# 81                        (Director_Shyam Benegal)
# 83                        (Director_T.L.V. Prasad)
# 85                        (Director_T.L.V. Prasad)
# 87                          (Director_Vijay Anand)
# 89                         (Director_Vikram Bhatt)
# 91                          (Director_Yash Chopra)
# 270            (Director_B.R. Ishara, Genre_Drama)
# 271  (Director_B.R. Ishara, Rating_Quantiles_Good)
# 273                         (Director_B.R. Ishara)
#
#                               consequents  antecedent support  \
# 0                 (Rating_Quantiles_Poor)            0.001374
# 3            (Rating_Quantiles_Excellent)            0.001460
# 4                           (Genre_Drama)            0.003435
# 6              (Rating_Quantiles_Average)            0.003435
# 8                 (Rating_Quantiles_Good)            0.003435
# 10             (Rating_Quantiles_Average)            0.003606
# 13           (Rating_Quantiles_Excellent)            0.003005
# 14           (Rating_Quantiles_Excellent)            0.001374
# 17           (Rating_Quantiles_Excellent)            0.001546
# 19                (Rating_Quantiles_Poor)            0.003692
# 20                (Rating_Quantiles_Poor)            0.001717
# 23             (Rating_Quantiles_Average)            0.002318
# 25           (Rating_Quantiles_Excellent)            0.001460
# 27                (Rating_Quantiles_Poor)            0.002490
# 29           (Rating_Quantiles_Excellent)            0.003606
# 30                (Rating_Quantiles_Poor)            0.002662
# 33                (Rating_Quantiles_Poor)            0.001546
# 35                         (Genre_Action)            0.004293
# 36                (Rating_Quantiles_Poor)            0.004293
# 39                         (Genre_Action)            0.002834
# 40                (Rating_Quantiles_Poor)            0.002834
# 43                         (Genre_Action)            0.001546
# 45                          (Genre_Drama)            0.003950
# 47                (Rating_Quantiles_Poor)            0.003950
# 49             (Rating_Quantiles_Average)            0.003950
# 51                         (Genre_Action)            0.002834
# 53             (Rating_Quantiles_Average)            0.002834
# 54             (Rating_Quantiles_Average)            0.002834
# 57                (Rating_Quantiles_Poor)            0.001975
# 59           (Rating_Quantiles_Excellent)            0.002748
# 61           (Rating_Quantiles_Excellent)            0.002233
# 63                (Rating_Quantiles_Poor)            0.002834
# 64                (Rating_Quantiles_Poor)            0.003005
# 67                (Rating_Quantiles_Poor)            0.003005
# 69           (Rating_Quantiles_Excellent)            0.002404
# 71           (Rating_Quantiles_Excellent)            0.003263
# 72             (Rating_Quantiles_Average)            0.001889
# 75                (Rating_Quantiles_Poor)            0.003005
# 77             (Rating_Quantiles_Average)            0.003005
# 79                          (Genre_Drama)            0.001975
# 81           (Rating_Quantiles_Excellent)            0.001975
# 83                         (Genre_Action)            0.002576
# 85                (Rating_Quantiles_Poor)            0.002576
# 87           (Rating_Quantiles_Excellent)            0.001460
# 89                (Rating_Quantiles_Poor)            0.002834
# 91           (Rating_Quantiles_Excellent)            0.001889
# 270               (Rating_Quantiles_Good)            0.001374
# 271                         (Genre_Drama)            0.001460
